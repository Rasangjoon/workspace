# %%
import pandas as pd
import numpy as np

# %%
dataan = pd.read_csv('dataana.csv', encoding = 'cp949')
dataan
# Out:
#            Date                               Title        Company  \
# 0    2024-03-26              AI 머신러닝 데이터분석가 등 경력 채용   (주)에이아이더뉴트리진
# 1    2024-03-26                     데이터분석가 모집 (수원시)     (주)케이알랩바이오
# 2    2024-03-26             [넛지헬스케어] 데이터분석가 - 석사/박사      넛지헬스케어(주)
# 3    2024-03-26           데이터엔지니어 데이터분석가 및 AI개발자 모집       (주)아이티공간
# 4    2024-03-26              [IP빅데이터분석팀] 특허 빅데이터분석가     (주)워트인텔리전스
# ..          ...                                 ...            ...
# 294  2024-03-26              시계열 데이터 엔지니어링 데이터 사이언스    쓰리알이노베이션(주)
# 295  2024-03-26            함께 성장할 빅데이터분석 지원자를 모십니다.        포체인스(주)
# 296  2024-03-26  인공지능/딥러닝 기반 문화콘텐츠 기술연구원[전문연구요원 가능]          (주)닷밀
# 297  2024-03-26    충북대학교 보건과학융합연구소 2024년도 연구원 3차 채용  충청북도공공보건의료지원단
# 298  2024-03-26             소프트웨어 / 데이터 사이언스 개발자 채용       (주)로그엔코딩
#
#                                                    URL    Deadline  \
# 0    http://www.saramin.co.kr/zf_user/jobs/relay/vi...  ~ 03/31(일)
# ...
